# %%
import requests
import json
from bs4 import BeautifulSoup
URL = []
for page in range(0,1):#MAX1025，頁數
    resp = requests.get('https://www.thenewslens.com/news?page=%s'%page)
    soup = BeautifulSoup(resp.text,'html5lib')
    selects = soup.select('div.info-box > a')
    for i in selects:
        if i.get('href').startswith('https://www.thenewslens.com/article/'):
            URL_news = i.get('href')
            print(URL_news)
            URL.append(URL_news)
with open('URL_news_sample','w') as f:
    f.write(json.dumps(URL))
# Out:
# https://www.thenewslens.com/article/81382
# https://www.thenewslens.com/article/82775
# https://www.thenewslens.com/article/82742
# https://www.thenewslens.com/article/82729
# https://www.thenewslens.com/article/82719
# https://www.thenewslens.com/article/82716
# https://www.thenewslens.com/article/82710
# https://www.thenewslens.com/article/82709
# https://www.thenewslens.com/article/82685
# https://www.thenewslens.com/article/82681
# https://www.thenewslens.com/article/82679
# https://www.thenewslens.com/article/82666
# https://www.thenewslens.com/article/82669
# https://www.thenewslens.com/article/82649
# https://www.thenewslens.com/article/82644
# https://www.thenewslens.com/article/82551
# https://www.thenewslens.com/article/82637
# https://www.thenewslens.com/article/82629

# %%
import pandas as pd
import csv
import json
with open('URL_news_sample','r') as f:
    r = f.read()
URLs = r.strip('[]').replace('"','').split(',')


pd_list=[]

for url in URLs:
    resp1 = requests.get(url)
    soup1 = BeautifulSoup(resp1.text,'html5lib')
    
    select1 = soup1.select('h1.article-title')
    select2 = soup1.select('div.article-info')
    select3 = soup1.select('div.article-content > p')
    
    article = {}
    article['title']=select1[0].text
#     print(article['title'])
    article['date'] =select2[0].text.strip().split(',')[0].strip()
    article['class'] =select2[0].text.split(',')[1].strip()
    pd_list.append(article)

    
df = pd.DataFrame(pd_list)
df.to_csv('Thenewslans_sample.csv')
print(df)
# Out:
#    class        date                                     title
# 0     運動  2017/11/06                 中信兄弟一口氣釋出7個人，「五虎將」只留下兩位
# 1     社會  2017/11/06     讓遊俄男子被註銷戶籍的中國「邊境專用護照」，只有台灣人跟中國人可以申請
# 2     運動  2017/11/06          體育協會不甩《國體法》？體總撤掉民眾入會系統、決議不開放直選
# 3     社會  2017/11/06       上千公頃工業區只進駐一家廠商，賴清德提3策略解決產業缺地、囤地問題
# 4     國際  2017/11/06          巴拿馬文件2.0：「天堂文件」揭露英國女皇、美國部長海外金庫
# 5     國際  2017/11/06               美國德州教堂遭槍手掃射，至少26人死亡、10人受傷
# 6     政治  2017/11/05        《勞基法》七休一鬆綁「已是共識」，若通過勞工連續上班12天不違法
# 7     國際  2017/11/05               受害者愈爆愈多，Netflix不再與凱文史貝西合作
# 8     政治  2017/11/05        陸委會否定雙北赴中設「辦事處」，柯文哲：中央做得好就不用麻煩地方
# 9     藝文  2017/11/05    「我的文學屬於台灣」國家文藝獎得主鄭清文辭世，留下300篇台灣土地的故事
# 10    國際  2017/11/05        沙國王儲主導反貪腐委員會，逮捕11名王子、4位部長與數十名前官員
# 11    社會  2017/11/04    首次《身權公約》審查：只用「生病」的角度看待身心障礙者，是台灣最大的問題
# 12    政治  2017/11/04          英國求職網站稱台灣「中國的一省」，可能源自於這個「國際標準」
# 13    社會  2017/11/04       中國每年「海漂」500公噸廢棄物給金門，未來可能用「垃圾船」運回去
# 14    社會  2017/11/04            仲裁要求台東縣府用12億買回美麗灣？縣長：我們已經夠窮了
# 15    社會  2017/11/03         【影音】替立委站台、開直播賺外快——遠航工會成員遭解僱後的告白
# 16    政治  2017/11/03          《產創條例》三讀：投資新創最多可抵稅300萬，比新加坡還優惠
# 17    國際  2017/11/03     【影音】埃及大金字塔發現飛機大小的神秘「空間」，4500年來無人觸及！

# %%
df.sort_values('class') #按類別排序
# Out:
#    class        date                                     title
# 17    國際  2017/11/03     【影音】埃及大金字塔發現飛機大小的神秘「空間」，4500年來無人觸及！
# 10    國際  2017/11/05        沙國王儲主導反貪腐委員會，逮捕11名王子、4位部長與數十名前官員
# 4     國際  2017/11/06          巴拿馬文件2.0：「天堂文件」揭露英國女皇、美國部長海外金庫
# 5     國際  2017/11/06               美國德州教堂遭槍手掃射，至少26人死亡、10人受傷
# 7     國際  2017/11/05               受害者愈爆愈多，Netflix不再與凱文史貝西合作
# 12    政治  2017/11/04          英國求職網站稱台灣「中國的一省」，可能源自於這個「國際標準」
# 16    政治  2017/11/03          《產創條例》三讀：投資新創最多可抵稅300萬，比新加坡還優惠
# 8     政治  2017/11/05        陸委會否定雙北赴中設「辦事處」，柯文哲：中央做得好就不用麻煩地方
# 6     政治  2017/11/05        《勞基法》七休一鬆綁「已是共識」，若通過勞工連續上班12天不違法
# 3     社會  2017/11/06       上千公頃工業區只進駐一家廠商，賴清德提3策略解決產業缺地、囤地問題
# 11    社會  2017/11/04    首次《身權公約》審查：只用「生病」的角度看待身心障礙者，是台灣最大的問題
# 1     社會  2017/11/06     讓遊俄男子被註銷戶籍的中國「邊境專用護照」，只有台灣人跟中國人可以申請
# 13    社會  2017/11/04       中國每年「海漂」500公噸廢棄物給金門，未來可能用「垃圾船」運回去
# 14    社會  2017/11/04            仲裁要求台東縣府用12億買回美麗灣？縣長：我們已經夠窮了
# 15    社會  2017/11/03         【影音】替立委站台、開直播賺外快——遠航工會成員遭解僱後的告白
# 9     藝文  2017/11/05    「我的文學屬於台灣」國家文藝獎得主鄭清文辭世，留下300篇台灣土地的故事
# 2     運動  2017/11/06          體育協會不甩《國體法》？體總撤掉民眾入會系統、決議不開放直選
# 0     運動  2017/11/06                 中信兄弟一口氣釋出7個人，「五虎將」只留下兩位
